# %% [markdown]
# # Donnée de stock
#
# Dans les données de stock, il y a un stock inital a date du 5 mai 2017 et un ensemble de stock initial délivré à différent intervals.
#
#
#
# ## Documentation
#
# - [Doc INSEE](https://scm.saas.cagip.group.gca/PERNETTH/database/blob/master/Documentation/IMR/Doc_Tech_IMR_Mai_2019_v1.5.1.pdf)
# - [etalab](https://github.com/etalab/rncs_worker_api_entreprise)
#     - [Module data cleaning](https://github.com/etalab/rncs_worker_api_entreprise/blob/master/clean_csv.bash)
# - Path local: `C:\Users\PERNETTH\Documents\Projects\GitLab\CreationDataBase\INPI\TC_1\Stock\Stock_initial`
# - Path Reseau: `G:\Projets\PP2019\2019_PROGRAMME BATICA\DATA\INPI\sources\IMR_Donnees_Saisies\tc\stock\2017`
#
# ### Variables communes
#
# ![image](https://drive.google.com/uc?export=view&id=1laCGFEtxM4bbckNZQEkw1icBjF4pd20-)
#
# ### Stock
#
# Le contenu de chaque fichier est disponible [ici](https://scm.saas.cagip.group.gca/PERNETTH/database/tree/master/INPI/TC_1)
#
# Les données brutes sont répertoriées dans des fichiers zip composées de 7 fichiers:
#
# - Actes
# - Comptes Annuels
# - ETS
# - OBS
# - PM
# - PP
# - REP
#
# ### Donnees de flux
#
# - Path local: `C:\Users\PERNETTH\Documents\Projects\GitLab\CreationDataBase\INPI\TC_1\Flux`
# - Path Reseau: `G:\Projets\PP2019\2019_PROGRAMME BATICA\DATA\INPI\sources\IMR_Donnees_Saisies\tc\Flux`
#
# Les PP en local sont disponibles ici: `C:\Users\PERNETTH\Documents\Projects\GitLab\CreationDataBase\INPI\TC_1\Flux\PP`
#
# name csv : `0101_1_20170512_112544_4_PP_EVT`
#
#     - code greffe: 0101
#     - numéro transmission: 1
#     - Date: 2017-05-12
#     - heures: 11h25m44s
#     - Type: PP
#     - Evenement: Oui
#
# **FICHIERS TRANSMIS EN CAS DE MISE A JOUR D’UN DOSSIER (EVENEMENT)**
#
# En cas de mise à jour d’un dossier suite à un événement (modification, radiation), les fichiers transmis ont une structure identique aux fichiers créés à l’immatriculation avec la présence de 2 champs spécifiques : la date de l’événement (Date_Greffe) et le libellé de l’événement (Libelle_Evt).
#
# Dans ces cas, 6 types de fichiers supplémentaires, numérotés, sont transmis correspondant à :
# * Evénements modifiant ou complétant les dossiers d’immatriculation des personnes morales (2) ou physiques (4)
# * Evénements modifiant ou complétant les informations relatives aux représentants (6) ou aux établissements (9)
# * Evénements supprimant des représentants (7 – Représentant partant) ou des établissements (10 – Etablissement supprimé)
#
# ![](https://drive.google.com/uc?export=view&id=1FVEGNqogl1NxB84BtdF4TQztCXjmtpyo)
#
# Attention, il peut arriver que le même dossier fasse l’objet de plusieurs événements (création et modification) dans la même transmission. Il est impératif d’intégrer les événements dans l’ordre d’apparition.
#
# Les csv sont classés de la manière suivante:
#
# - Module (ETS, PP, PM, etc)
#     - NEW: New event
#     - EVT: Update event

# %%
import pandas as pd
import inpi

# %%
path_stock = r"C:\Users\PERNETTH\Documents\Projects\GitLab\CreationDataBase\INPI\TC_1\Stock\Stock_initial"
path_flux = r"C:\Users\PERNETTH\Documents\Projects\GitLab\CreationDataBase\INPI\TC_1\Flux"

# %% [markdown]
# ## PP

# %%
dtype = {
    "Code Greffe": "int",
    "Nom_Greffe": "str",
    "Numero_Gestion": "str",
    "Siren": "int",
    "Type_Inscription": "str",
    "Date_Immatriculation": "str",
    "Date_1re_Immatriculation": "str",
    "Date_Radiation": "str",
    "Date_Transfert": "str",
    "Sans_Activité": "str",
    "Date_Debut_Activité": "str",
    "Date_Début_1re_Activité": "str",
    "Date_Cessation_Activité": "str",
    "Nom_Patronymique": "str",
    "Nom_Usage": "str",
    "Pseudonyme": "str",
    "Prénoms": "str",
    "Date_Naissance": "str",
    "Ville_Naissance": "str",
    "Pays_Naissance": "str",
    "Nationalité": "str",
    "Adresse_Ligne1": "str",
    "Adresse_Ligne2": "str",
    "Adresse_Ligne3": "str",
    "Code_Postal": "str",
    "Ville": "str",
    "Code_Commune": "str",
    "Pays": "str",
    "Activité_Forain": "str",
    "EIRL": "str",
    "Auto-entrepreneur": "str",
    "DAP": "str",
    "DAP_Dénomination": "str",
    "DAP_Objet": "str",
    "DAP_Date_Clôture": "str",
    "DAP_Adresse_Ligne1": "str",
    "DAP_Adresse_Ligne2": "str",
    "DAP_Adresse_Ligne3": "str",
    "DAP_Code_Postal": "str",
    "DAP_Ville": "str",
    "DAP_Code_Commune": "str",
    "DAP_Pays": "str",
    "Conjoint_Collab_Nom_Patronym": "str",
    "Conjoint_Collab_Nom_Usage": "str",
    "Conjoint_Collab_Pseudo": "str",
    "Conjoint_Collab_Prénoms": "str",
    "Conjoint_Collab_Date_Fin": "str",
    "Date_Greffe": "str",
    "Libelle_Evt": "str",
}

parse_dates = [
    "Date_Immatriculation",
    "Date_1re_Immatriculation",
    "Date_Radiation",
    "Date_Transfert",
    "Date_Debut_Activité",
    "Date_Début_1re_Activité",
    "Date_Cessation_Activité",
    "Date_Naissance",
    "DAP_Date_Clôture",
    "Date_Greffe",
]

# %%
inpi.appendData(
    origin="PP",
    EVT=False,
    dtype=dtype,
    parse_date=parse_dates,
    path=path_stock,
    list_unique=False,
)
# Out:
#         Code Greffe       Nom_Greffe Numero_Gestion      Siren  \
# 0               101  Bourg-en-Bresse     2002A00253  442377040
# 1               101  Bourg-en-Bresse     2015A00093  809861297
# 2               101  Bourg-en-Bresse     2005A00087  480952712
# 3               101  Bourg-en-Bresse     1992A00503  388239667
# 4               101  Bourg-en-Bresse     2017A00279  828427245
# ...             ...              ...            ...        ...
# 758467         9401          Créteil     2016A01477  822165775
# 758468         9401          Créteil     2000A00192  429710312
# 758469         9401          Créteil     2013A00106  411165590
# 758470         9401          Créteil     2016A00542  819097445
# 758471         9401          Créteil     2015A00338  528246713
#
#        Type_Inscription Date_Immatriculation Date_1re_Immatriculation  \
# 0                     P           2002-06-18                      NaT
# 1                     P           2015-02-27                      NaT
# 2                     P           2005-02-23                      NaT
# 3                     P           1992-10-14                      NaT
# 4                     P           2017-04-18                      NaT
# ...                 ...                  ...                      ...
# 758467                P           2016-09-02                      NaT
# 758468                P           2000-03-01                      NaT
# 758469                P           2013-04-30                      NaT
# 758470                P           2016-03-16                      NaT
# 758471                P           2015-05-06                      NaT
#
#        Date_Radiation Date_Transfert Sans_Activité  ...          DAP_Ville  \
# 0                 NaT            NaT           NaN  ...                NaN
# 1                 NaT            NaT           NaN  ...                NaN
# 2                 NaT            NaT           NaN  ...                NaN
# 3                 NaT            NaT           NaN  ...                NaN
# 4                 NaT            NaT           NaN  ...                NaN
# ...               ...            ...           ...  ...                ...
# 758467            NaT            NaT           NaN  ...                NaN
# 758468            NaT            NaT           NaN  ...                NaN
# 758469            NaT            NaT           NaN  ...                NaN
# 758470            NaT            NaT           NaN  ...  Joinville-le-Pont
# 758471            NaT     2015-01-01           NaN  ...                NaN
#
#        DAP_Code_Commune DAP_Pays Conjoint_Collab_Nom_Patronym  \
# 0                   NaN      NaN                          NaN
# 1                   NaN      NaN                          NaN
# 2                   NaN      NaN                          NaN
# 3                   NaN      NaN                          NaN
# 4                   NaN      NaN                          NaN
# ...                 ...      ...                          ...
# 758467              NaN      NaN                          NaN
# 758468              NaN      NaN                          NaN
# 758469              NaN      NaN                          NaN
# 758470              NaN   FRANCE                          NaN
# 758471              NaN      NaN                          NaN
#
#        Conjoint_Collab_Nom_Usage Conjoint_Collab_Pseudo  \
# 0                            NaN                    NaN
# 1                            NaN                    NaN
# 2                            NaN                    NaN
# 3                            NaN                    NaN
# 4                            NaN                    NaN
# ...                          ...                    ...
# 758467                       NaN                    NaN
# 758468                       NaN                    NaN
# 758469                       NaN                    NaN
# 758470                       NaN                    NaN
# 758471                       NaN                    NaN
#
#        Conjoint_Collab_Prénoms Conjoint_Collab_Date_Fin Date_Greffe  \
# 0                          NaN                      NaN  2015-08-04
# 1                          NaN                      NaN  2015-02-27
# 2                          NaN                      NaN  2017-05-03
# 3                          NaN                      NaN  2017-05-03
# 4                          NaN                      NaN  2017-04-18
# ...                        ...                      ...         ...
# 758467                     NaN                      NaN  2016-09-06
# 758468                     NaN                      NaN  2017-05-04
# 758469                     NaN                      NaN  2015-08-20
# 758470                     NaN                      NaN  2016-03-17
# 758471                     NaN                      NaN  2015-05-06
#
#        Libelle_Evt
# 0         Création
# 1         Création
# 2         Création
# 3         Création
# 4         Création
# ...            ...
# 758467    Création
# 758468    Création
# 758469    Création
# 758470    Création
# 758471    Création
#
# [758472 rows x 49 columns]

# %%
inpi.appendData(
    origin="PP",
    EVT=False,
    dtype=dtype,
    parse_date=parse_dates,
    path=path_flux,
    list_unique=False,
)
# Out:
#       Code Greffe       Nom_Greffe Numero_Gestion      Siren Type_Inscription  \
# 0             101  Bourg-en-Bresse     2017A00322  829341635                P
# 1             101  Bourg-en-Bresse     2017A00323  829344324                P
# 2             101  Bourg-en-Bresse     2017A00327  829386515                P
# 3             101  Bourg-en-Bresse     2017A00325  803040583                P
# 4             101  Bourg-en-Bresse     2017A00324  393826185                P
# ...           ...              ...            ...        ...              ...
# 3896         9401          Créteil     2017A00633  825199995                P
# 3897         9401          Créteil     2017A00643  829444736                P
# 3898         9401          Créteil     2017A00624  393161302                P
# 3899         9401          Créteil     2017A00621  418006946                P
# 3900         9401          Créteil     2017A00622  829380955                P
#
#      Date_Immatriculation Date_1re_Immatriculation Date_Radiation  \
# 0              2017-05-04                      NaT            NaT
# 1              2017-05-04                      NaT            NaT
# 2              2017-05-05                      NaT            NaT
# 3              2017-05-05                      NaT            NaT
# 4              2017-05-05                      NaT            NaT
# ...                   ...                      ...            ...
# 3896           2017-05-05                      NaT            NaT
# 3897           2017-05-10                      NaT            NaT
# 3898           2017-05-05                      NaT            NaT
# 3899           2017-05-05                      NaT            NaT
# 3900           2017-05-05                      NaT            NaT
#
#      Date_Transfert Sans_Activité  ... DAP_Ville DAP_Code_Commune DAP_Pays  \
# 0               NaT           NaN  ...       NaN              NaN      NaN
# 1               NaT           NaN  ...       NaN              NaN      NaN
# 2               NaT           NaN  ...       NaN              NaN      NaN
# 3               NaT           NaN  ...       NaN              NaN      NaN
# 4               NaT           NaN  ...       NaN              NaN      NaN
# ...             ...           ...  ...       ...              ...      ...
# 3896            NaT           NaN  ...       NaN              NaN      NaN
# 3897            NaT           NaN  ...       NaN              NaN      NaN
# 3898            NaT           NaN  ...  Valenton              NaN   FRANCE
# 3899            NaT           NaN  ...       NaN              NaN      NaN
# 3900            NaT           NaN  ...       NaN              NaN      NaN
#
#      Conjoint_Collab_Nom_Patronym Conjoint_Collab_Nom_Usage  \
# 0                             NaN                       NaN
# 1                             NaN                       NaN
# 2                             NaN                       NaN
# 3                             NaN                       NaN
# 4                             NaN                       NaN
# ...                           ...                       ...
# 3896                          NaN                       NaN
# 3897                          NaN                       NaN
# 3898                          NaN                       NaN
# 3899                          NaN                       NaN
# 3900                          NaN                       NaN
#
#      Conjoint_Collab_Pseudo Conjoint_Collab_Prénoms Conjoint_Collab_Date_Fin  \
# 0                       NaN                     NaN                      NaN
# 1                       NaN                     NaN                      NaN
# 2                       NaN                     NaN                      NaN
# 3                       NaN                     NaN                      NaN
# 4                       NaN                     NaN                      NaN
# ...                     ...                     ...                      ...
# 3896                    NaN                     NaN                      NaN
# 3897                    NaN                     NaN                      NaN
# 3898                    NaN                     NaN                      NaN
# 3899                    NaN                     NaN                      NaN
# 3900                    NaN                     NaN                      NaN
#
#      Date_Greffe Libelle_Evt
# 0     2017-05-04    Création
# 1     2017-05-04    Création
# 2     2017-05-05    Création
# 3     2017-05-05    Création
# 4     2017-05-05    Création
# ...          ...         ...
# 3896  2017-05-05    Création
# 3897  2017-05-10    Création
# 3898  2017-05-05    Création
# 3899  2017-05-05    Création
# 3900  2017-05-05    Création
#
# [3901 rows x 49 columns]

# %%
inpi.appendData(
    origin="PP",
    EVT=True,
    dtype=dtype,
    parse_date=parse_dates,
    path=path_flux,
    list_unique=False,
)
# Out:
#       Code Greffe       Nom_Greffe Numero_Gestion      Siren Type_Inscription  \
# 0             101  Bourg-en-Bresse     2017A00108  827575812                P
# 1             101  Bourg-en-Bresse     2012A00186  345104111                P
# 2             101  Bourg-en-Bresse     2015A00356  753507268                P
# 3             101  Bourg-en-Bresse     2015A00263  421891409                P
# 4             101  Bourg-en-Bresse     2016A00675  821933645                P
# ...           ...              ...            ...        ...              ...
# 2629         9401          Créteil     2005A00749  484004767                P
# 2630         9401          Créteil     2002A00313  441608171                P
# 2631         9401          Créteil     2016A00704  819534140                P
# 2632         9401          Créteil     2011A00066  530838929                P
# 2633         9401          Créteil     2016A00546  522807221                P
#
#      Date_Immatriculation Date_1re_Immatriculation       Date_Radiation  \
# 0                     NaT                      NaT  2017-05-04 00:00:00
# 1                     NaT                      NaT  2017-05-04 00:00:00
# 2                     NaT                      NaT  2017-05-04 00:00:00
# 3                     NaT                      NaT                  NaT
# 4                     NaT                      NaT  2017-05-05 00:00:00
# ...                   ...                      ...                  ...
# 2629                  NaT                      NaT  2017-05-10 00:00:00
# 2630                  NaT                      NaT                  NaT
# 2631                  NaT                      NaT  2017-05-10 00:00:00
# 2632                  NaT                      NaT  2017-05-10 00:00:00
# 2633                  NaT                      NaT                  NaT
#
#      Date_Transfert Sans_Activité  ...        DAP_Ville DAP_Code_Commune  \
# 0               NaT           NaN  ...              NaN              NaN
# 1               NaT           NaN  ...              NaN              NaN
# 2               NaT           NaN  ...              NaN              NaN
# 3               NaT           NaN  ...              NaN              NaN
# 4               NaT           NaN  ...              NaN              NaN
# ...             ...           ...  ...              ...              ...
# 2629            NaT           NaN  ...              NaN              NaN
# 2630            NaT           NaN  ...  Vitry-sur-Seine              NaN
# 2631            NaT           NaN  ...              NaN              NaN
# 2632            NaT           NaN  ...              NaN              NaN
# 2633            NaT           NaN  ...              NaN              NaN
#
#      DAP_Pays Conjoint_Collab_Nom_Patronym Conjoint_Collab_Nom_Usage  \
# 0         NaN                          NaN                       NaN
# 1         NaN                          NaN                       NaN
# 2         NaN                          NaN                       NaN
# 3         NaN                          NaN                       NaN
# 4         NaN                          NaN                       NaN
# ...       ...                          ...                       ...
# 2629      NaN                          NaN                       NaN
# 2630   FRANCE                          NaN                       NaN
# 2631      NaN                          NaN                       NaN
# 2632      NaN                          NaN                       NaN
# 2633      NaN                          NaN                       NaN
#
#      Conjoint_Collab_Pseudo Conjoint_Collab_Prénoms Conjoint_Collab_Date_Fin  \
# 0                       NaN                     NaN                      NaN
# 1                       NaN                     NaN                      NaN
# 2                       NaN                     NaN                      NaN
# 3                       NaN                     NaN                      NaN
# 4                       NaN                     NaN                      NaN
# ...                     ...                     ...                      ...
# 2629                    NaN                     NaN                      NaN
# 2630                    NaN                     NaN                      NaN
# 2631                    NaN                     NaN                      NaN
# 2632                    NaN                     NaN                      NaN
# 2633                    NaN                     NaN                      NaN
#
#      Date_Greffe                         Libelle_Evt
# 0     2017-05-04  Modifications relatives au dossier
# 1     2017-05-04  Modifications relatives au dossier
# 2     2017-05-04  Modifications relatives au dossier
# 3     2017-05-04  Modifications relatives au dossier
# 4     2017-05-05  Modifications relatives au dossier
# ...          ...                                 ...
# 2629  2017-05-10  Modifications relatives au dossier
# 2630  2017-05-10  Modifications relatives au dossier
# 2631  2017-05-10  Modifications relatives au dossier
# 2632  2017-05-10  Modifications relatives au dossier
# 2633  2017-05-10  Modifications relatives au dossier
#
# [2634 rows x 49 columns]

# %%
df_pp_initial.loc[lambda x: x["Siren"].isin([827575812])].T

# %%
df_pp_update.loc[lambda x: x["Siren"].isin([827575812])].T

# %% [markdown]
# ## PM

# %%
dtype = {
    "Code Greffe": "int",
    "Nom_Greffe": "str",
    "Numero_Gestion": "str",
    "Siren": "int",
    "Type_Inscription": "str",
    "Date_Immatriculation": "str",
    "Date_1re_Immatriculation": "str",
    "Date_Radiation": "str",
    "Date_Transfert": "str",
    "Sans_Activité": "str",
    "Date_Debut_Activité": "str",
    "Date_Début_1re_Activité": "str",
    "Date_Cessation_Activité": "str",
    "Denomination": "str",
    "Sigle": "str",
    "Forme_Juridique": "str",
    "Associé_Unique": "str",
    "Activité_Principale": "str",
    "Type_Capital": "str",
    "Capital": "float64",
    "Capital_Actuel": "float64",
    "Devise": "str",
    "Date_Clôture": "str",
    "Date_Clôture_Except.": "str",
    "Economie_Sociale_Solidaire": "str",
    "Durée_PM": pd.Int64Dtype(),
    "Date_Greffe": "str",
    "Libelle_Evt": "str",
}

parse_dates = [
    "Date_Immatriculation",
    "Date_1re_Immatriculation",
    "Date_Radiation",
    "Date_Transfert",
    "Date_Debut_Activité",
    "Date_Début_1re_Activité",
    "Date_Cessation_Activité",
    "Date_Clôture",
    "Date_Clôture_Except.",
    "Date_Greffe",
]

# %%
inpi.appendData(
    origin="PM",
    EVT=False,
    dtype=dtype,
    parse_date=parse_dates,
    path=path_stock,
    list_unique=False,
)
# Out:
#          Code Greffe       Nom_Greffe Numero_Gestion      Siren  \
# 0                101  Bourg-en-Bresse     2015B01079  813543063
# 1                101  Bourg-en-Bresse     2015B01297  800897092
# 2                101  Bourg-en-Bresse     2002D40001  440432052
# 3                101  Bourg-en-Bresse     2011D00505  534728381
# 4                101  Bourg-en-Bresse     2012B00425  750647851
# ...              ...              ...            ...        ...
# 4296547         9401          Créteil     2014B00125  799594270
# 4296548         9401          Créteil     2017D00077  824999809
# 4296549         9401          Créteil     2006B02127  490363058
# 4296550         9401          Créteil     2001D00529  438001844
# 4296551         9401          Créteil     2013D00829  794404608
#
#         Type_Inscription Date_Immatriculation Date_1re_Immatriculation  \
# 0                      P  2015-09-17 00:00:00               2015-09-17
# 1                      P  2015-11-06 00:00:00                      NaN
# 2                      P  2002-01-03 00:00:00                      NaN
# 3                      P  2011-09-21 00:00:00                      NaN
# 4                      P  2012-04-02 00:00:00                      NaN
# ...                  ...                  ...                      ...
# 4296547                P  2014-01-10 00:00:00                      NaT
# 4296548                P  2017-01-18 00:00:00      2017-01-18 00:00:00
# 4296549                P  2006-06-01 00:00:00                      NaT
# 4296550                P  2001-06-01 00:00:00                      NaT
# 4296551                P  2013-07-23 00:00:00                      NaT
#
#         Date_Radiation Date_Transfert Sans_Activité  ... Type_Capital  \
# 0                  NaT            NaT           NaN  ...            F
# 1                  NaT            NaT           NaN  ...            F
# 2                  NaT            NaT           NaN  ...            F
# 3                  NaT            NaT           NaN  ...            F
# 4                  NaT            NaT           NaN  ...            F
# ...                ...            ...           ...  ...          ...
# 4296547            NaT            NaT           NaN  ...            F
# 4296548            NaT            NaT           NaN  ...            F
# 4296549            NaT            NaT           NaN  ...            F
# 4296550            NaT            NaT           NaN  ...            F
# 4296551            NaT            NaT           NaN  ...            F
#
#             Capital Capital_Actuel Devise  Date_Clôture Date_Clôture_Except.  \
# 0        6000000.00            NaN  Euros   31 Décembre                  NaN
# 1         694400.00            NaN  Euros  30 Septembre                  NaN
# 2           8000.00            NaN  Euros   31 Décembre                  NaN
# 3          88000.00            NaN  Euros           NaN                  NaN
# 4          20000.00            NaN  Euros  30 Septembre           2013-09-30
# ...             ...            ...    ...           ...                  ...
# 4296547     1000.00            NaN  Euros   31 Décembre           2014-12-31
# 4296548     1500.00            NaN  Euros           NaN                  NaN
# 4296549     3000.00            NaN  Euros   31 Décembre           2007-12-31
# 4296550      146.35            NaN  Euros        31 Mai                  NaN
# 4296551      100.00            NaN  Euros           NaN                  NaN
#
#         Economie_Sociale_Solidaire Durée_PM          Date_Greffe  Libelle_Evt
# 0                              Non       15  2015-09-17 00:00:00     Création
# 1                              Non       98  2017-05-03 00:00:00     Création
# 2                              Non       99  2017-02-20 00:00:00     Création
# 3                              Non       80  2011-09-21 00:00:00     Création
# 4                              Non       50  2017-03-08 00:00:00     Création
# ...                            ...      ...                  ...          ...
# 4296547                        Non       99  2015-02-17 00:00:00     Création
# 4296548                        Non       99  2017-01-20 00:00:00     Création
# 4296549                        Non       99  2008-01-28 00:00:00     Création
# 4296550                        Non       99  2003-11-17 00:00:00     Création
# 4296551                        Non       99  2013-10-22 00:00:00     Création
#
# [4296552 rows x 28 columns]

# %%
inpi.appendData(
    origin="PM",
    EVT=False,
    dtype=dtype,
    parse_date=parse_dates,
    path=path_flux,
    list_unique=False,
)
# Out:
#       Code Greffe       Nom_Greffe Numero_Gestion      Siren Type_Inscription  \
# 0             101  Bourg-en-Bresse     2017B00697  829413665                P
# 1             101  Bourg-en-Bresse     2017B00699  829357912                P
# 2             101  Bourg-en-Bresse     2017B00701  829423953                P
# 3             101  Bourg-en-Bresse     2017D00289  829421650                P
# 4             101  Bourg-en-Bresse     2017B00696  829412410                P
# ...           ...              ...            ...        ...              ...
# 9725         9401          Créteil     2017B02678  829411180                P
# 9726         9401          Créteil     2017B02591  824803951                P
# 9727         9401          Créteil     2017B02672  828905877                P
# 9728         9401          Créteil     2017B02620  829366418                P
# 9729         9401          Créteil     2017B02720  829482199                P
#
#      Date_Immatriculation Date_1re_Immatriculation Date_Radiation  \
# 0              2017-05-04               2017-05-04            NaT
# 1              2017-05-04               2017-05-04            NaT
# 2              2017-05-04               2017-05-04            NaT
# 3              2017-05-04               2017-05-04            NaT
# 4              2017-05-04               2017-05-04            NaT
# ...                   ...                      ...            ...
# 9725           2017-05-05               2017-05-05            NaT
# 9726           2017-05-02               2017-05-02            NaT
# 9727           2017-05-05               2017-05-05            NaT
# 9728           2017-05-03               2017-05-03            NaT
# 9729           2017-05-10               2017-05-10            NaT
#
#      Date_Transfert Sans_Activité  ... Type_Capital  Capital Capital_Actuel  \
# 0               NaT           NaN  ...            F   1500.0            NaN
# 1               NaT           Oui  ...            F   2000.0            NaN
# 2               NaT           NaN  ...            F   1000.0            NaN
# 3               NaT           NaN  ...            F   1200.0            NaN
# 4               NaT           NaN  ...            F   2000.0            NaN
# ...             ...           ...  ...          ...      ...            ...
# 9725            NaT           NaN  ...            F   6000.0            NaN
# 9726            NaT           NaN  ...            F  10000.0            NaN
# 9727            NaT           NaN  ...            V   3000.0         3000.0
# 9728            NaT           NaN  ...            F   1000.0            NaN
# 9729            NaT           NaN  ...            F  10000.0            NaN
#
#      Devise Date_Clôture Date_Clôture_Except. Economie_Sociale_Solidaire  \
# 0     Euros  31 Décembre           2017-12-31                        Non
# 1     Euros      31 Mars           2018-03-31                        Non
# 2     Euros       31 Mai           2018-05-31                        Non
# 3     Euros          NaN                  NaT                        Non
# 4     Euros  31 Décembre           2018-12-31                        Non
# ...     ...          ...                  ...                        ...
# 9725  Euros  31 Décembre           2017-12-31                        Non
# 9726  Euros  31 Décembre           2017-12-31                        Non
# 9727  Euros  31 Décembre           2018-12-31                        Non
# 9728  Euros  31 Décembre           2017-12-31                        Non
# 9729  Euros  31 Décembre           2017-12-31                        Non
#
#      Durée_PM Date_Greffe  Libelle_Evt
# 0          99  2017-05-04     Création
# 1          99  2017-05-04     Création
# 2          99  2017-05-04     Création
# 3          99  2017-05-04     Création
# 4          99  2017-05-04     Création
# ...       ...         ...          ...
# 9725       99  2017-05-09     Création
# 9726       99  2017-05-04     Création
# 9727       99  2017-05-05     Création
# 9728       99  2017-05-04     Création
# 9729       99  2017-05-10     Création
#
# [9730 rows x 28 columns]

# %%
inpi.appendData(
    origin="PM",
    EVT=False,
    dtype=dtype,
    parse_date=parse_dates,
    path=path_flux,
    list_unique=False,
)
# Out:
#       Code Greffe       Nom_Greffe Numero_Gestion      Siren Type_Inscription  \
# 0             101  Bourg-en-Bresse     2017B00697  829413665                P
# 1             101  Bourg-en-Bresse     2017B00699  829357912                P
# 2             101  Bourg-en-Bresse     2017B00701  829423953                P
# 3             101  Bourg-en-Bresse     2017D00289  829421650                P
# 4             101  Bourg-en-Bresse     2017B00696  829412410                P
# ...           ...              ...            ...        ...              ...
# 9725         9401          Créteil     2017B02678  829411180                P
# 9726         9401          Créteil     2017B02591  824803951                P
# 9727         9401          Créteil     2017B02672  828905877                P
# 9728         9401          Créteil     2017B02620  829366418                P
# 9729         9401          Créteil     2017B02720  829482199                P
#
#      Date_Immatriculation Date_1re_Immatriculation Date_Radiation  \
# 0              2017-05-04               2017-05-04            NaT
# 1              2017-05-04               2017-05-04            NaT
# 2              2017-05-04               2017-05-04            NaT
# 3              2017-05-04               2017-05-04            NaT
# 4              2017-05-04               2017-05-04            NaT
# ...                   ...                      ...            ...
# 9725           2017-05-05               2017-05-05            NaT
# 9726           2017-05-02               2017-05-02            NaT
# 9727           2017-05-05               2017-05-05            NaT
# 9728           2017-05-03               2017-05-03            NaT
# 9729           2017-05-10               2017-05-10            NaT
#
#      Date_Transfert Sans_Activité  ... Type_Capital  Capital Capital_Actuel  \
# 0               NaT           NaN  ...            F   1500.0            NaN
# 1               NaT           Oui  ...            F   2000.0            NaN
# 2               NaT           NaN  ...            F   1000.0            NaN
# 3               NaT           NaN  ...            F   1200.0            NaN
# 4               NaT           NaN  ...            F   2000.0            NaN
# ...             ...           ...  ...          ...      ...            ...
# 9725            NaT           NaN  ...            F   6000.0            NaN
# 9726            NaT           NaN  ...            F  10000.0            NaN
# 9727            NaT           NaN  ...            V   3000.0         3000.0
# 9728            NaT           NaN  ...            F   1000.0            NaN
# 9729            NaT           NaN  ...            F  10000.0            NaN
#
#      Devise Date_Clôture Date_Clôture_Except. Economie_Sociale_Solidaire  \
# 0     Euros  31 Décembre           2017-12-31                        Non
# 1     Euros      31 Mars           2018-03-31                        Non
# 2     Euros       31 Mai           2018-05-31                        Non
# 3     Euros          NaN                  NaT                        Non
# 4     Euros  31 Décembre           2018-12-31                        Non
# ...     ...          ...                  ...                        ...
# 9725  Euros  31 Décembre           2017-12-31                        Non
# 9726  Euros  31 Décembre           2017-12-31                        Non
# 9727  Euros  31 Décembre           2018-12-31                        Non
# 9728  Euros  31 Décembre           2017-12-31                        Non
# 9729  Euros  31 Décembre           2017-12-31                        Non
#
#      Durée_PM Date_Greffe  Libelle_Evt
# 0          99  2017-05-04     Création
# 1          99  2017-05-04     Création
# 2          99  2017-05-04     Création
# 3          99  2017-05-04     Création
# 4          99  2017-05-04     Création
# ...       ...         ...          ...
# 9725       99  2017-05-09     Création
# 9726       99  2017-05-04     Création
# 9727       99  2017-05-05     Création
# 9728       99  2017-05-04     Création
# 9729       99  2017-05-10     Création
#
# [9730 rows x 28 columns]

# %% [markdown]
# ## REP
#
# Doc REP: https://scm.saas.cagip.group.gca/PERNETTH/database/blob/master/Documentation/IMR/Doc_Tech_IMR_Mai_2019_v1.5.1.pdf
# - page 30
#
# Attention, certains champs sont remplis selon le type de la société. Ex SIREN -> Si type =PM
#
# Pourquoi deux SIREN?
#
# Le deuxième siren correspond a celui de la PM qui detient l'entreprise.
#
# Ex: Peugeot a plusieurs détenteur. Le détenteur possède un siren, il sera affiché dans siren.1 uniquement si détenteur est une PM

# %%
dtype = {
    "Code Greffe": "int",
    "Nom_Greffe": "str",
    "Numero_Gestion": "str",
    "Siren": "int",
    "Type": "str",
    "Nom_Patronymique": "str",
    "Nom_Usage": "str",
    "Pseudonyme": "str",
    "Prénoms": "str",
    "Dénomination": "str",
    "Siren.1": "str",
    "Forme_Juridique": "str",
    "Adresse_Ligne1": "str",
    "Adresse_Ligne2": "str",
    "Adresse_Ligne3": "str",
    "Code_Postal": "str",
    "Ville": "str",
    "Code_Commune": "str",
    "Pays": "str",
    "Date_Naissance": "str",
    "Ville_Naissance": "str",
    "Pays_Naissance": "str",
    "Nationalité": "str",
    "Qualité": "str",
    "Rep_Perm_Nom": "str",
    "Rep_Perm_Nom_Usage": "str",
    "Rep_Perm_Pseudo": "str",
    "Rep_Perm_Prénoms": "str",
    "Rep_Perm_Date_Naissance": "str",
    "Rep_Perm_Ville_Naissance": "str",
    "Rep_Perm_Pays_Naissance": "str",
    "Rep_Perm_Nationalité": "str",
    "Rep_Perm_Adr_Ligne1": "str",
    "Rep_Perm_Adr_Ligne2": "str",
    "Rep_Perm_Adr_Ligne3": "str",
    "Rep_Perm_Code_Postal": "str",
    "Rep_Perm_Ville": "str",
    "Rep_Perm_Code_Commune": "str",
    "Rep_Perm_Pays": "str",
    "Conjoint_Collab_Nom_Patronym": "str",
    "Conjoint_Collab_Nom_Usage": "str",
    "Conjoint_Collab_Pseudo": "str",
    "Conjoint_Collab_Prénoms": "str",
    "Conjoint_Collab_Date_Fin": "str",
    "ID_Représentant": "str",
    "date_greffe": "str",
    "Libelle_Evt": "str",
}

parse_dates = ["Date_Naissance", "date_greffe"]

# %%
inpi.appendData(
    origin="REP",
    EVT=False,
    dtype=dtype,
    parse_date=parse_dates,
    path=path_stock,
    list_unique=False,
)
# Out:
#          Code Greffe       Nom_Greffe Numero_Gestion      Siren        Type  \
# 0                101  Bourg-en-Bresse     2015B01079  813543063  P.Physique
# 1                101  Bourg-en-Bresse     2015B01079  813543063  P.Physique
# 2                101  Bourg-en-Bresse     2015B01079  813543063  P.Physique
# 3                101  Bourg-en-Bresse     2015B01079  813543063  P.Physique
# 4                101  Bourg-en-Bresse     2015B01297  800897092  P.Physique
# ...              ...              ...            ...        ...         ...
# 9504902         9401          Créteil     2001D00529  438001844  P.Physique
# 9504903         9401          Créteil     2013D00829  794404608  P.Physique
# 9504904         9401          Créteil     2013D00829  794404608  P.Physique
# 9504905         9401          Créteil     2013D00829  794404608  P.Physique
# 9504906         9401          Créteil     2013D00829  794404608   P. Morale
#
#         Nom_Patronymique          Nom_Usage Pseudonyme          Prénoms  \
# 0           MARGARITELLI                NaN        NaN            Dario
# 1           MARGARITELLI                NaN        NaN            Dario
# 2               LUCARINI                NaN        NaN          Stefano
# 3           MARGARITELLI                NaN        NaN           Andrea
# 4              CHANUSSOT  MENDES DE FREITAS        NaN        Françoise
# ...                  ...                ...        ...              ...
# 9504902          BREMAUD            JONQUET        NaN  Annie Francette
# 9504903           DURAND                NaN        NaN        Charlotte
# 9504904           DURAND                NaN        NaN        Charlotte
# 9504905           DURAND                NaN        NaN           Claude
# 9504906              NaN                NaN        NaN              NaN
#
#                       Dénomination  ... Rep_Perm_Code_Commune Rep_Perm_Pays  \
# 0                              NaN  ...                   NaN           NaN
# 1                              NaN  ...                   NaN           NaN
# 2                              NaN  ...                   NaN           NaN
# 3                              NaN  ...                   NaN           NaN
# 4                              NaN  ...                   NaN           NaN
# ...                            ...  ...                   ...           ...
# 9504902                        NaN  ...                   NaN           NaN
# 9504903                        NaN  ...                   NaN           NaN
# 9504904                        NaN  ...                   NaN           NaN
# 9504905                        NaN  ...                   NaN           NaN
# 9504906  CABINET DU DOCTEUR DURAND  ...                   NaN           NaN
#
#         Conjoint_Collab_Nom_Patronym Conjoint_Collab_Nom_Usage  \
# 0                                NaN                       NaN
# 1                                NaN                       NaN
# 2                                NaN                       NaN
# 3                                NaN                       NaN
# 4                                NaN                       NaN
# ...                              ...                       ...
# 9504902                          NaN                       NaN
# 9504903                          NaN                       NaN
# 9504904                          NaN                       NaN
# 9504905                          NaN                       NaN
# 9504906                          NaN                       NaN
#
#         Conjoint_Collab_Pseudo Conjoint_Collab_Prénoms  \
# 0                          NaN                     NaN
# 1                          NaN                     NaN
# 2                          NaN                     NaN
# 3                          NaN                     NaN
# 4                          NaN                     NaN
# ...                        ...                     ...
# 9504902                    NaN                     NaN
# 9504903                    NaN                     NaN
# 9504904                    NaN                     NaN
# 9504905                    NaN                     NaN
# 9504906                    NaN                     NaN
#
#         Conjoint_Collab_Date_Fin ID_Représentant          date_greffe  \
# 0                            NaN               1  2015-09-17 00:00:00
# 1                            NaN               1  2015-09-17 00:00:00
# 2                            NaN               2  2015-09-17 00:00:00
# 3                            NaN               3  2015-09-17 00:00:00
# 4                            NaN               1  2017-05-03 00:00:00
# ...                          ...             ...                  ...
# 9504902                      NaN              12  2003-11-17 00:00:00
# 9504903                      NaN               1  2013-10-22 00:00:00
# 9504904                      NaN               1  2013-10-22 00:00:00
# 9504905                      NaN               2  2013-10-22 00:00:00
# 9504906                      NaN               3  2013-10-22 00:00:00
#
#                Libelle_Evt
# 0        Nouveau dirigeant
# 1        Nouveau dirigeant
# 2        Nouveau dirigeant
# 3        Nouveau dirigeant
# 4        Nouveau dirigeant
# ...                    ...
# 9504902  Nouveau dirigeant
# 9504903  Nouveau dirigeant
# 9504904  Nouveau dirigeant
# 9504905  Nouveau dirigeant
# 9504906  Nouveau dirigeant
#
# [9504907 rows x 47 columns]

# %%
inpi.appendData(
    origin="REP",
    EVT=False,
    dtype=dtype,
    parse_date=parse_dates,
    path=path_flux,
    list_unique=False,
)
# Out:
#        Code Greffe       Nom_Greffe Numero_Gestion      Siren        Type  \
# 0              101  Bourg-en-Bresse     2017B00697  829413665  P.Physique
# 1              101  Bourg-en-Bresse     2017B00699  829357912  P.Physique
# 2              101  Bourg-en-Bresse     2017B00701  829423953  P.Physique
# 3              101  Bourg-en-Bresse     2017D00289  829421650  P.Physique
# 4              101  Bourg-en-Bresse     2017D00289  829421650  P.Physique
# ...            ...              ...            ...        ...         ...
# 20094         9401          Créteil     2017B02678  829411180  P.Physique
# 20095         9401          Créteil     2017B02591  824803951  P.Physique
# 20096         9401          Créteil     2017B02672  828905877  P.Physique
# 20097         9401          Créteil     2017B02620  829366418  P.Physique
# 20098         9401          Créteil     2017B02720  829482199  P.Physique
#
#       Nom_Patronymique Nom_Usage Pseudonyme                Prénoms  \
# 0               LAUNAY       NaN        NaN  Jérôme, Marc, Patrick
# 1             BEREZIAT    GAVAND        NaN               Charline
# 2             FOURNIER       NaN        NaN              Guillaume
# 3              BALUFIN       NaN        NaN                Thierry
# 4              BALUFIN       NaN        NaN                Thierry
# ...                ...       ...        ...                    ...
# 20094           KONATE       NaN        NaN                 Bineta
# 20095      ABDELHAFIDH       NaN        NaN                   Imad
# 20096          ZARROUK       NaN        NaN                  Fathi
# 20097        VASIKARAN       NaN        NaN                Kandiah
# 20098            ZUILI       NaN        NaN                 Robert
#
#       Dénomination  ... Rep_Perm_Code_Commune Rep_Perm_Pays  \
# 0              NaN  ...                   NaN           NaN
# 1              NaN  ...                   NaN           NaN
# 2              NaN  ...                   NaN           NaN
# 3              NaN  ...                   NaN           NaN
# 4              NaN  ...                   NaN           NaN
# ...            ...  ...                   ...           ...
# 20094          NaN  ...                   NaN           NaN
# 20095          NaN  ...                   NaN           NaN
# 20096          NaN  ...                   NaN           NaN
# 20097          NaN  ...                   NaN           NaN
# 20098          NaN  ...                   NaN           NaN
#
#       Conjoint_Collab_Nom_Patronym Conjoint_Collab_Nom_Usage  \
# 0                              NaN                       NaN
# 1                              NaN                       NaN
# 2                              NaN                       NaN
# 3                              NaN                       NaN
# 4                              NaN                       NaN
# ...                            ...                       ...
# 20094                          NaN                       NaN
# 20095                          NaN                       NaN
# 20096                          NaN                       NaN
# 20097                          NaN                       NaN
# 20098                          NaN                       NaN
#
#       Conjoint_Collab_Pseudo Conjoint_Collab_Prénoms Conjoint_Collab_Date_Fin  \
# 0                        NaN                     NaN                      NaN
# 1                        NaN                     NaN                      NaN
# 2                        NaN                     NaN                      NaN
# 3                        NaN                     NaN                      NaN
# 4                        NaN                     NaN                      NaN
# ...                      ...                     ...                      ...
# 20094                    NaN                     NaN                      NaN
# 20095                    NaN                     NaN                      NaN
# 20096                    NaN                     NaN                      NaN
# 20097                    NaN                     NaN                      NaN
# 20098                    NaN                     NaN                      NaN
#
#       ID_Représentant date_greffe        Libelle_Evt
# 0                   1  2017-05-04  Nouveau dirigeant
# 1                   1  2017-05-04  Nouveau dirigeant
# 2                   1  2017-05-04  Nouveau dirigeant
# 3                   1  2017-05-04  Nouveau dirigeant
# 4                   1  2017-05-04  Nouveau dirigeant
# ...               ...         ...                ...
# 20094               1  2017-05-09  Nouveau dirigeant
# 20095               1  2017-05-04  Nouveau dirigeant
# 20096               1  2017-05-05  Nouveau dirigeant
# 20097               1  2017-05-04  Nouveau dirigeant
# 20098               1  2017-05-10  Nouveau dirigeant
#
# [20099 rows x 47 columns]

# %%
inpi.appendData(
    origin="REP",
    EVT=False,
    dtype=dtype,
    parse_date=parse_dates,
    path=path_flux,
    list_unique=False,
)
# Out:
#        Code Greffe       Nom_Greffe Numero_Gestion      Siren        Type  \
# 0              101  Bourg-en-Bresse     2017B00697  829413665  P.Physique
# 1              101  Bourg-en-Bresse     2017B00699  829357912  P.Physique
# 2              101  Bourg-en-Bresse     2017B00701  829423953  P.Physique
# 3              101  Bourg-en-Bresse     2017D00289  829421650  P.Physique
# 4              101  Bourg-en-Bresse     2017D00289  829421650  P.Physique
# ...            ...              ...            ...        ...         ...
# 20094         9401          Créteil     2017B02678  829411180  P.Physique
# 20095         9401          Créteil     2017B02591  824803951  P.Physique
# 20096         9401          Créteil     2017B02672  828905877  P.Physique
# 20097         9401          Créteil     2017B02620  829366418  P.Physique
# 20098         9401          Créteil     2017B02720  829482199  P.Physique
#
#       Nom_Patronymique Nom_Usage Pseudonyme                Prénoms  \
# 0               LAUNAY       NaN        NaN  Jérôme, Marc, Patrick
# 1             BEREZIAT    GAVAND        NaN               Charline
# 2             FOURNIER       NaN        NaN              Guillaume
# 3              BALUFIN       NaN        NaN                Thierry
# 4              BALUFIN       NaN        NaN                Thierry
# ...                ...       ...        ...                    ...
# 20094           KONATE       NaN        NaN                 Bineta
# 20095      ABDELHAFIDH       NaN        NaN                   Imad
# 20096          ZARROUK       NaN        NaN                  Fathi
# 20097        VASIKARAN       NaN        NaN                Kandiah
# 20098            ZUILI       NaN        NaN                 Robert
#
#       Dénomination  ... Rep_Perm_Code_Commune Rep_Perm_Pays  \
# 0              NaN  ...                   NaN           NaN
# 1              NaN  ...                   NaN           NaN
# 2              NaN  ...                   NaN           NaN
# 3              NaN  ...                   NaN           NaN
# 4              NaN  ...                   NaN           NaN
# ...            ...  ...                   ...           ...
# 20094          NaN  ...                   NaN           NaN
# 20095          NaN  ...                   NaN           NaN
# 20096          NaN  ...                   NaN           NaN
# 20097          NaN  ...                   NaN           NaN
# 20098          NaN  ...                   NaN           NaN
#
#       Conjoint_Collab_Nom_Patronym Conjoint_Collab_Nom_Usage  \
# 0                              NaN                       NaN
# 1                              NaN                       NaN
# 2                              NaN                       NaN
# 3                              NaN                       NaN
# 4                              NaN                       NaN
# ...                            ...                       ...
# 20094                          NaN                       NaN
# 20095                          NaN                       NaN
# 20096                          NaN                       NaN
# 20097                          NaN                       NaN
# 20098                          NaN                       NaN
#
#       Conjoint_Collab_Pseudo Conjoint_Collab_Prénoms Conjoint_Collab_Date_Fin  \
# 0                        NaN                     NaN                      NaN
# 1                        NaN                     NaN                      NaN
# 2                        NaN                     NaN                      NaN
# 3                        NaN                     NaN                      NaN
# 4                        NaN                     NaN                      NaN
# ...                      ...                     ...                      ...
# 20094                    NaN                     NaN                      NaN
# 20095                    NaN                     NaN                      NaN
# 20096                    NaN                     NaN                      NaN
# 20097                    NaN                     NaN                      NaN
# 20098                    NaN                     NaN                      NaN
#
#       ID_Représentant date_greffe        Libelle_Evt
# 0                   1  2017-05-04  Nouveau dirigeant
# 1                   1  2017-05-04  Nouveau dirigeant
# 2                   1  2017-05-04  Nouveau dirigeant
# 3                   1  2017-05-04  Nouveau dirigeant
# 4                   1  2017-05-04  Nouveau dirigeant
# ...               ...         ...                ...
# 20094               1  2017-05-09  Nouveau dirigeant
# 20095               1  2017-05-04  Nouveau dirigeant
# 20096               1  2017-05-05  Nouveau dirigeant
# 20097               1  2017-05-04  Nouveau dirigeant
# 20098               1  2017-05-10  Nouveau dirigeant
#
# [20099 rows x 47 columns]

# %% [markdown]
# ## ETS

# %%
dtype = {
    "Code Greffe": "int",
    "Nom_Greffe": "str",
    "Numero_Gestion": "str",
    "Siren": "int",
    "Type": "str",
    "Siège_PM": "str",
    "RCS_Registre": "str",
    "Adresse_Ligne1": "str",
    "Adresse_Ligne2": "str",
    "Adresse_Ligne3": "str",
    "Code_Postal": "str",
    "Ville": "str",
    "Code_Commune": "str",
    "Pays": "str",
    "Domiciliataire_Nom": "str",
    "Domiciliataire_Siren": "str",
    "Domiciliataire_Greffe": "str",
    "Domiciliataire_Complément": "str",
    "Siege_Domicile_Représentant": "str",
    "Nom_Commercial": "str",
    "Enseigne": "str",
    "Activité_Ambulante": "str",
    "Activité_Saisonnière": "str",
    "Activité_Non_Sédentaire": "str",
    "Date_Début_Activité": "str",
    "Activité": "str",
    "Origine_Fonds": "str",
    "Origine_Fonds_Info": "str",
    "Type_Exploitation": "str",
    "ID_Etablissement": "int",
    "Date_Greffe": "str",
    "Libelle_Evt": "str",
}

parse_dates = ["Date_Début_Activité", "Date_Greffe"]

# %%
inpi.appendData(
    origin="ETS",
    EVT=False,
    dtype=dtype,
    parse_date=parse_dates,
    path=path_stock,
    list_unique=False,
)
# Out:
#          Code Greffe       Nom_Greffe Numero_Gestion      Siren Type Siège_PM  \
# 0                101  Bourg-en-Bresse     2015B01079  813543063  PRI      NaN
# 1                101  Bourg-en-Bresse     2015B01297  800897092  SEP      NaN
# 2                101  Bourg-en-Bresse     2002D40001  440432052  SEP      NaN
# 3                101  Bourg-en-Bresse     2011D00505  534728381  SEP      NaN
# 4                101  Bourg-en-Bresse     2012B00425  750647851  SEP      NaN
# ...              ...              ...            ...        ...  ...      ...
# 7575457         9401          Créteil     2001D00529  438001844  SIE      NaN
# 7575458         9401          Créteil     2001D00529  438001844  PRI      NaN
# 7575459         9401          Créteil     2015A00338  528246713  PRI      NaN
# 7575460         9401          Créteil     2013D00829  794404608  SIE      NaN
# 7575461         9401          Créteil     2013D00829  794404608  PRI      NaN
#
#         RCS_Registre              Adresse_Ligne1            Adresse_Ligne2  \
# 0                NaN                         NaN                   RD 1075
# 1                NaN                         NaN  640 route de Montgrimoux
# 2                NaN                         NaN            13 rue du Plat
# 3                NaN                         NaN  chemin des Bourbouillons
# 4                NaN                         NaN   638 rue Aimé Bonneville
# ...              ...                         ...                       ...
# 7575457          NaN  78 Avenue Maurice Berteaux                       NaN
# 7575458          NaN  78 Avenue Maurice Berteaux                       NaN
# 7575459          NaN  5 Rue du Maréchal Vaillant                       NaN
# 7575460          NaN      125 Boulevard Galliéni                       NaN
# 7575461          NaN      125 Boulevard Galliéni                       NaN
#
#         Adresse_Ligne3  ... Activité_Saisonnière Activité_Non_Sédentaire  \
# 0              la Gare  ...                  non                     non
# 1                  NaN  ...                  non                     non
# 2                  NaN  ...                  non                     non
# 3                  NaN  ...                  non                     non
# 4                  NaN  ...                  non                     non
# ...                ...  ...                  ...                     ...
# 7575457            NaN  ...                  NaN                     NaN
# 7575458            NaN  ...                  non                     non
# 7575459            NaN  ...                  non                     non
# 7575460            NaN  ...                  NaN                     NaN
# 7575461            NaN  ...                  non                     non
#
#         Date_Début_Activité  \
# 0                2015-10-01
# 1                2015-07-03
# 2                2002-01-01
# 3                2011-09-01
# 4                2014-08-01
# ...                     ...
# 7575457                 NaN
# 7575458          2001-06-15
# 7575459          2015-01-01
# 7575460                 NaN
# 7575461          2013-06-10
#
#                                                   Activité  \
# 0        Industrie pour la production et la pose de pro...
# 1        Acquisition, gestion des titres de toutes soci...
# 2           L'exercice libéral de la profession de médecin
# 3                                      Production laitière
# 4                                  Transaction immobilière
# ...                                                    ...
# 7575457                                                NaN
# 7575458  Acquisition et mise en valeur des biens immobi...
# 7575459                          Production audiovisuelle.
# 7575460                                                NaN
# 7575461  Acquisition administration gestion par locatio...
#
#                                        Origine_Fonds  \
# 0                                           Création
# 1        Transfert d'activité (origine hors ressort)
# 2                                           Création
# 3                                           Création
# 4                                           Création
# ...                                              ...
# 7575457                                          NaN
# 7575458                                       Divers
# 7575459                                     Création
# 7575460                                          NaN
# 7575461                                     Création
#
#                                         Origine_Fonds_Info  \
# 0                                                      NaN
# 1        ransfert d'activité (origine hors ressort) - C...
# 2                                                      NaN
# 3                                                      NaN
# 4                                                      NaN
# ...                                                    ...
# 7575457                                                NaN
# 7575458                                              -  -
# 7575459                                                NaN
# 7575460                                                NaN
# 7575461                                                NaN
#
#             Type_Exploitation ID_Etablissement          Date_Greffe  \
# 0        Exploitation directe                1  2015-09-17 00:00:00
# 1        Exploitation directe                1  2017-05-03 00:00:00
# 2        Exploitation directe                1  2017-02-20 00:00:00
# 3        Exploitation directe                1  2011-09-21 00:00:00
# 4        Exploitation directe                2  2017-03-08 00:00:00
# ...                       ...              ...                  ...
# 7575457                   NaN                0  2003-11-17 00:00:00
# 7575458                   NaN               10  2003-11-17 00:00:00
# 7575459  Exploitation directe                2  2015-05-06 00:00:00
# 7575460                   NaN                1  2013-10-22 00:00:00
# 7575461                   NaN                2  2013-10-22 00:00:00
#
#                   Libelle_Evt
# 0        Etablissement ouvert
# 1        Etablissement ouvert
# 2        Etablissement ouvert
# 3        Etablissement ouvert
# 4        Etablissement ouvert
# ...                       ...
# 7575457  Etablissement ouvert
# 7575458  Etablissement ouvert
# 7575459  Etablissement ouvert
# 7575460  Etablissement ouvert
# 7575461  Etablissement ouvert
#
# [7575462 rows x 32 columns]

# %%
inpi.appendData(
    origin="ETS",
    EVT=False,
    dtype=dtype,
    parse_date=parse_dates,
    path=path_flux,
    list_unique=False,
)
# Out:
#        Code Greffe       Nom_Greffe Numero_Gestion      Siren Type Siège_PM  \
# 0              101  Bourg-en-Bresse     2017B00697  829413665  SEP      NaN
# 1              101  Bourg-en-Bresse     2017B00699  829357912  SIE      NaN
# 2              101  Bourg-en-Bresse     2017B00701  829423953  SEP      NaN
# 3              101  Bourg-en-Bresse     2017A00322  829341635  PRI      NaN
# 4              101  Bourg-en-Bresse     2017D00289  829421650  SEP      NaN
# ...            ...              ...            ...        ...  ...      ...
# 18701         9401          Créteil     2017B02620  829366418  PRI      NaN
# 18702         9401          Créteil     2017A00621  418006946  PRI      NaN
# 18703         9401          Créteil     2017B02720  829482199  SIE      NaN
# 18704         9401          Créteil     2017B02720  829482199  PRI      NaN
# 18705         9401          Créteil     2017A00622  829380955  PRI      NaN
#
#       RCS_Registre           Adresse_Ligne1              Adresse_Ligne2  \
# 0              NaN                      NaN      1593 route de Civrieux
# 1              NaN                      NaN            6 route de Bourg
# 2              NaN                      NaN                6 Grande rue
# 3              NaN                      NaN        6 place de la Mairie
# 4              NaN                      NaN  1143 rue Claires Fontaines
# ...            ...                      ...                         ...
# 18701          NaN    2 Rue François Villon                         NaN
# 18702          NaN   10 Rue Gaston Margerie                         NaN
# 18703          NaN      5 Rue Louis Marchal                         NaN
# 18704          NaN      5 Rue Louis Marchal                         NaN
# 18705          NaN  48 Rue Germain Defresne                         NaN
#
#         Adresse_Ligne3  ... Activité_Saisonnière Activité_Non_Sédentaire  \
# 0                  NaN  ...                  non                     non
# 1                  NaN  ...                  NaN                     NaN
# 2                  NaN  ...                  non                     non
# 3      Hôtel du Centre  ...                  non                     non
# 4                  NaN  ...                  non                     non
# ...                ...  ...                  ...                     ...
# 18701              NaN  ...                  non                     non
# 18702              NaN  ...                  non                     non
# 18703              NaN  ...                  NaN                     NaN
# 18704              NaN  ...                  non                     non
# 18705              NaN  ...                  non                     non
#
#       Date_Début_Activité                                           Activité  \
# 0              2017-04-01  Dispense de cours de yoga consultation psychol...
# 1                     NaT                                                NaN
# 2              2017-05-02  Tous travaux protant sur les canalisations d'e...
# 3              2017-04-01  Prestations de services en matière de restaura...
# 4              2017-04-13  L'acquisition par voie d'achat ou d'apport la ...
# ...                   ...                                                ...
# 18701          2017-05-01        Restauration de type rapide (sans alcools).
# 18702          2017-05-09                                       E commerce.
# 18703                 NaT                                                NaN
# 18704          2017-04-25  Les prestations de services en matière d'infor...
# 18705          2017-04-01  Non sédentaire, prêt à porter HFE, maroquineri...
#
#       Origine_Fonds Origine_Fonds_Info         Type_Exploitation  \
# 0          Création                NaN      Exploitation directe
# 1               NaN                NaN                       NaN
# 2          Création                NaN      Exploitation directe
# 3          Création                NaN  Exploitation personnelle
# 4          Création                NaN                       NaN
# ...             ...                ...                       ...
# 18701      Création                NaN      Exploitation directe
# 18702      Création                NaN      Exploitation directe
# 18703           NaN                NaN                       NaN
# 18704      Création                NaN      Exploitation directe
# 18705      Création                NaN      Exploitation directe
#
#       ID_Etablissement Date_Greffe           Libelle_Evt
# 0                    1  2017-05-04  Etablissement ouvert
# 1                    0  2017-05-04  Etablissement ouvert
# 2                    1  2017-05-04  Etablissement ouvert
# 3                    1  2017-05-04  Etablissement ouvert
# 4                    1  2017-05-04  Etablissement ouvert
# ...                ...         ...                   ...
# 18701                2  2017-05-04  Etablissement ouvert
# 18702                2  2017-05-05  Etablissement ouvert
# 18703                1  2017-05-10  Etablissement ouvert
# 18704                2  2017-05-10  Etablissement ouvert
# 18705                2  2017-05-05  Etablissement ouvert
#
# [18706 rows x 32 columns]

# %%
inpi.appendData(
    origin="ETS",
    EVT=True,
    dtype=dtype,
    parse_date=parse_dates,
    path=path_flux,
    list_unique=False,
)
# Out:
#       Code Greffe       Nom_Greffe Numero_Gestion      Siren Type Siège_PM  \
# 0             101  Bourg-en-Bresse     2014B00348  510957269  PRI      NaN
# 1             101  Bourg-en-Bresse     2016B00332  818866915  PRI      NaN
# 2             101  Bourg-en-Bresse     1993C00001  390802940  PRI      NaN
# 3             101  Bourg-en-Bresse     2015B00634  811369362  SEC      NaN
# 4             101  Bourg-en-Bresse     2017B00048  824330559  SEP      NaN
# ...           ...              ...            ...        ...  ...      ...
# 9479         9401          Créteil     2016A00546  522807221  PRI      NaN
# 9480         9401          Créteil     2017B00202  824822241  PRI      NaN
# 9481         9401          Créteil     2017B01433  828170159  PRI      NaN
# 9482         9401          Créteil     2017B01433  828170159  PRI      NaN
# 9483         9401          Créteil     2017B01433  828170159  PRI      NaN
#
#      RCS_Registre                       Adresse_Ligne1  \
# 0             NaN                                  NaN
# 1             NaN                                  NaN
# 2             NaN                                  NaN
# 3             NaN                                  NaN
# 4             NaN                                  NaN
# ...           ...                                  ...
# 9479          NaN           105 Rue du Général Leclerc
# 9480          NaN  11-13 Avenue de la Division Leclerc
# 9481          NaN                 19 Avenue du Château
# 9482          NaN                 19 Avenue du Château
# 9483          NaN                 19 Avenue du Château
#
#                                 Adresse_Ligne2     Adresse_Ligne3  ...  \
# 0                           1476 route de Lyon                NaN  ...
# 1                               21 les Acacias  Cité des Folliets  ...
# 2     Immeuble "Ceregrain" 76 avenue de Marboz                NaN  ...
# 3                           impasse des Prunus     Sur les Combes  ...
# 4                646 avenue des Prés Seigneurs                NaN  ...
# ...                                        ...                ...  ...
# 9479                                       NaN                NaN  ...
# 9480                                       NaN                NaN  ...
# 9481                                       NaN                NaN  ...
# 9482                                       NaN                NaN  ...
# 9483                                       NaN                NaN  ...
#
#      Activité_Saisonnière Activité_Non_Sédentaire Date_Début_Activité  \
# 0                     NaN                     NaN                 NaT
# 1                     NaN                     NaN                 NaT
# 2                     NaN                     NaN                 NaT
# 3                     non                     non          2017-03-27
# 4                     NaN                     NaN                 NaT
# ...                   ...                     ...                 ...
# 9479                  NaN                     NaN                 NaT
# 9480                  NaN                     NaN                 NaT
# 9481                  NaN                     NaN                 NaT
# 9482                  non                     non          2017-05-05
# 9483                  non                     non          2017-05-05
#
#                                                Activité Origine_Fonds  \
# 0                                                   NaN           NaN
# 1                                                   NaN           NaN
# 2                                                   NaN           NaN
# 3                     Tuyauteur, soudeur, chaudronnier.      Création
# 4                                                   NaN           NaN
# ...                                                 ...           ...
# 9479                                                NaN           NaN
# 9480  Production et édition phonographique, entrepre...           NaN
# 9481  Restaurant, traiteur, vente de plats à emporte...           NaN
# 9482  Restaurant, traiteur, vente de plats à emporte...         Achat
# 9483  Restaurant, traiteur, vente de plats à emporte...         Achat
#
#                           Origine_Fonds_Info     Type_Exploitation  \
# 0                                        NaN                   NaN
# 1                                        NaN                   NaN
# 2                                        NaN                   NaN
# 3                                        NaN  Exploitation directe
# 4                                        NaN                   NaN
# ...                                      ...                   ...
# 9479                                     NaN                   NaN
# 9480                                     NaN                   NaN
# 9481                                     NaN                   NaN
# 9482   - Précédent exploitant - CHATEAU D'OR  Exploitation directe
# 9483   - Précédent exploitant - CHATEAU D'OR  Exploitation directe
#
#      ID_Etablissement Date_Greffe                                 Libelle_Evt
# 0                   1  2017-05-04                      Etablissement supprimé
# 1                   1  2017-05-04                      Etablissement supprimé
# 2                   1  2017-05-04                      Etablissement supprimé
# 3                   2  2017-05-04                        Etablissement ouvert
# 4                   1  2017-05-04  Modifications relatives à un établissement
# ...               ...         ...                                         ...
# 9479                2  2017-05-10  Modifications relatives à un établissement
# 9480                2  2017-05-10  Modifications relatives à un établissement
# 9481                2  2017-05-10  Modifications relatives à un établissement
# 9482                2  2017-05-10  Modifications relatives à un établissement
# 9483                2  2017-05-10  Modifications relatives à un établissement
#
# [9484 rows x 32 columns]

# %% [markdown]
# ## ACTES

# %%
dtype = {
    'Code Greffe':'int',
 'Nom_Greffe':'str',
 'Numero_Gestion':'str',
 'Siren':'int',
 'Date_Dépôt':'str',
 'Numéro_Dépôt':'str',
 'Date_Acte':'str',
 'Type_Acte':'str',
 'Décision':'str',
 'Etat':'str'
}

parse_dates = ["Date_Dépôt", "Date_Acte"]

# %%
inpi.appendData(
    origin="ACTES",
    EVT=False,
    dtype=dtype,
    parse_date=parse_dates,
    path=path_stock,
    list_unique=False,
)

# %%
inpi.appendData(
    origin="ACTES",
    EVT=False,
    dtype=dtype,
    parse_date=parse_dates,
    path=path_flux,
    list_unique=False,
)

# %%
inpi.appendData(
    origin="ACTES",
    EVT=True,
    dtype=dtype,
    parse_date=parse_dates,
    path=path_flux,
    list_unique=False,
)

# %% [markdown]
# ## COMPTES ANNUELS

# %%
dtype = {
    'Code Greffe':'int',
 'Nom_Greffe':'str',
 'Numero_Gestion':'str',
 'Siren':'int',
 'Date_Dépôt':'str',
 'Numéro_Dépôt':'str',
 'Date_Clôture':'str',
 'Durée_Exercice':pd.Int64Dtype(),
 'Type_Remise':'str',
 'Confidentialité':'str',
 'Confidentialité_Compte_résultat':'str',
 'Etat':'str'
}

parse_dates = ["Date_Dépôt", "Date_Clôture"]

# %%
inpi.appendData(
    origin="COMPTES_ANNUELS",
    EVT=False,
    dtype=dtype,
    parse_date=parse_dates,
    path=path_stock,
    list_unique=False,
)

# %%
inpi.appendData(
    origin="COMPTES_ANNUELS",
    EVT=False,
    dtype=dtype,
    parse_date=parse_dates,
    path=path_flux,
    list_unique=False,
)

# %%
inpi.appendData(
    origin="COMPTES_ANNUELS",
    EVT=True,
    dtype=dtype,
    parse_date=parse_dates,
    path=path_flux,
    list_unique=False,
)

# %% [markdown]
# ## OBS

# %%
dtype = {
    'Code Greffe':'int',
 'Nom_Greffe':'str',
 'Numero_Gestion':'str',
 'Siren':'int',
 'ID_Observation':'int',
 'Numéro_Observation':'int',
 'Date_Ajout':'str',
 'Date_Suppression':'str',
 'Texte':'str',
 'Date_Greffe':'str',
 'Etat ':'str'
}

parse_dates = ["Date_Ajout", "Date_Suppression", "Date_Greffe"]

# %%
inpi.appendData(
    origin="OBS",
    EVT=False,
    dtype=dtype,
    parse_date=parse_dates,
    path=path_stock,
    list_unique=False,
)

# %%
inpi.appendData(
    origin="OBS",
    EVT=False,
    dtype=dtype,
    parse_date=parse_dates,
    path=path_flux,
    list_unique=False,
)

# %%
inpi.appendData(
    origin="OBS",
    EVT=True,
    dtype=dtype,
    parse_date=parse_dates,
    path=path_flux,
    list_unique=False,
)
