# %% [markdown]
# # Test SageMaker

# %%
import boto3
import pandas as pd
from sagemaker import get_execution_role

#https://finditcalf.s3.eu-west-3.amazonaws.com/test/0101_1_20170512_112544_1_PM.csv
role = get_execution_role()
bucket='test'
data_key = '0101_1_20170512_112544_1_PM.csv'
data_location = 'https://finditcalf.s3.eu-west-3.amazonaws.com/{}/{}'.format(bucket, data_key)

data_location
# Out:
# 'https://finditcalf.s3.eu-west-3.amazonaws.com/test/0101_1_20170512_112544_1_PM.csv'

# %%
pd.read_csv(data_location,sep=";")
# Out:
#     Code Greffe       Nom_Greffe Numero_Gestion      Siren Type_Inscription  \
# 0           101  Bourg-en-Bresse     2017B00696  829412410                P
# 1           101  Bourg-en-Bresse     2017B00709  829426089                P
# 2           101  Bourg-en-Bresse     2017B00703  829446152                P
# 3           101  Bourg-en-Bresse     2017D00289  829421650                P
# 4           101  Bourg-en-Bresse     2017B00697  829413665                P
# 5           101  Bourg-en-Bresse     2017D00298  829484591                P
# 6           101  Bourg-en-Bresse     2017B00711  829489616                P
# 7           101  Bourg-en-Bresse     2017B00700  829421031                P
# 8           101  Bourg-en-Bresse     2017D00296  341180255                P
# 9           101  Bourg-en-Bresse     2017D00295  829474774                P
# 10          101  Bourg-en-Bresse     2017B00704  829397611                P
# ...
