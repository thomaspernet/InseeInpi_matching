# %% [markdown]
# # Logs SIRETISATION

# %%
import glob, os, json
import pandas as pd
data = []
#os.chdir(r"data\logs\")
for file in glob.glob(r"data\logs\*.json"):
    with open(file) as f:
        for line in f:
            data.append(json.loads(line))

# %%
logs = pd.json_normalize(data)
logs
# Out:
#    key  total_to_siret_intial  total_stotal_siren_initialiren  \
# 0    0                7552898                         4811139
# 1    1                7552898                         4811139
# 2    2                7552898                         4811139
# 3    3                7552898                         4811139
# 4    4                7552898                         4811139
# 5    5                7552898                         4811139
# 6    6                7552898                         4811139
# 7    7                7552898                         4811139
#
#    total_to_siret_current  total_siren_current  total_match_rows_current  \
# 0                 7552898              4811139                   4381198
# 1                 3165545              2044055                    143812
# 2                 3017814              1956016                    435906
# 3                 2580979              1656872                     94699
# 4                 2484801              1593351                    169171
# 5                 2314273              1447362                    121983
# 6                 2191091              1371837                   1745786
# 7                  431554               341458                     50123
#
#    perc_total_match_rows_initial  total_match_siren_current  \
# 0                       0.580068                    2928274
# 1                       0.019041                     102142
# 2                       0.057714                     325529
# 3                       0.012538                      70967
# 4                       0.022398                     153929
# 5                       0.016150                      86145
# 6                       0.231141                    1070848
# 7                       0.006636                      32887
#
#    perc_total_match_siren_initial  perc_total_match_rows_current  \
# 0                        0.608645                       0.580068
# 1                        0.021230                       0.045430
# 2                        0.067662                       0.144444
# 3                        0.014751                       0.036691
# 4                        0.031994                       0.068082
# 5                        0.017905                       0.052709
# 6                        0.222577                       0.796766
# 7                        0.006836                       0.116145
#
#    perc_total_match_siren_current    check  df_no_duplication.nb_index  \
# 0                        0.608645  3187871                     4376190
# 1                        0.049970  3028718                      142279
# 2                        0.166425  2585673                      434488
# 3                        0.042832  2489419                       93869
# 4                        0.096607  2322103                      166613
# 5                        0.059519  2198063                      119696
# 6                        0.780594   535758                     1707435
# 7                        0.096313   383930                       49044
#
#    df_no_duplication.unique_siren  df_duplication.nb_index  \
# 0                         2924688                    11163
# 1                          101032                     5452
# 2                          324413                     2347
# 3                           70225                     2309
# 4                          152005                     3915
# 5                           84149                     3486
# 6                         1047666                    52102
# 7                           32180                     1420
#
#    df_duplication.unique_siren  \
# 0                         7958
# 1                         2211
# 2                         1821
# 3                         1567
# 4                         2799
# 5                         2598
# 6                        30341
# 7                          943
#
#    df_duplication.df_not_duplicate_index.nb_index  \
# 0                                            5008
# 1                                            1533
# 2                                            1418
# 3                                             830
# 4                                            2558
# 5                                            2287
# 6                                           38351
# 7                                            1079
#
#    df_duplication.df_not_duplicate_index.unique_siren  \
# 0                                               7958
# 1                                               2211
# 2                                               1821
# 3                                               1567
# 4                                               2799
# 5                                               2598
# 6                                              30341
# 7                                                943
#
#    df_duplication.df_sp_index.nb_index  \
# 0                                 6155
# 1                                 3919
# 2                                  929
# 3                                 1479
# 4                                 1357
# 5                                 1199
# 6                                13751
# 7                                  341
#
#    df_duplication.df_sp_index.unique_siren
# 0                                     4688
# 1                                     1261
# 2                                      783
# 3                                      882
# 4                                     1010
# 5                                      709
# 6                                     7987
# 7                                      250

# %%
logs[['total_match_rows_current']].sum()

# %%
logs[['perc_total_match_rows_initial']].sum()

# %%
logs[['perc_total_match_siren_initial']].sum()

# %%
logs[['perc_total_match_rows_initial',
      'perc_total_match_siren_initial']].plot.bar(stacked=False)

# %%
logs[['total_match_rows_current']].plot.bar(stacked=False)
