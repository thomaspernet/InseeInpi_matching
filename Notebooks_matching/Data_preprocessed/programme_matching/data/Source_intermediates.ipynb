# %% [markdown]
# # Source intermediate
#
# Dans ce notebook, il y a les informations relatives à la création des fichiers intermediares:
#
# - Communes

# %%
import dask.dataframe as dd
import pandas as pd
#import Match_inpi_insee.aws_connectors as aws
#from tqdm.notebook import tqdm
#import tqdm
# %load_ext autoreload
# %autoreload 2

# %%
path_commune = 'https://scm.saas.cagip.group.gca/PERNETTH/inseeinpi_matching/raw' \
'/master/Notebooks_matching/Data_preprocessed/programme_matching/data/input' \
'/RawParameters/communes-01012019.csv'

# %% [markdown]
# ## Créer fichier toutes les possibilités communes
#
# Le fichier provient de l'[INSEE](https://www.insee.fr/fr/information/3720946)

# %%
df = pd.read_csv(path_commune)

# %%
df.head()
# Out:
#   typecom    com   reg dep  arr  tncc                    ncc  \
# 0     COM  01001  84.0  01  012     5  ABERGEMENT CLEMENCIAT
# 1     COM  01002  84.0  01  011     5    ABERGEMENT DE VAREY
# 2     COM  01004  84.0  01  011     1      AMBERIEU EN BUGEY
# 3     COM  01005  84.0  01  012     1    AMBERIEUX EN DOMBES
# 4     COM  01006  84.0  01  011     1                AMBLEON
#
#                   nccenr                  libelle   can  comparent
# 0  Abergement-Clémenciat  L'Abergement-Clémenciat  0108        NaN
# 1    Abergement-de-Varey    L'Abergement-de-Varey  0101        NaN
# 2      Ambérieu-en-Bugey        Ambérieu-en-Bugey  0101        NaN
# 3    Ambérieux-en-Dombes      Ambérieux-en-Dombes  0122        NaN
# 4                Ambléon                  Ambléon  0104        NaN

# %%
(df
            .set_index('ncc')
            .reindex(columns=['nccenr', 'libelle'])
            .assign(
    noaccent=lambda x: x['nccenr'].str.normalize('NFKD')
    .str.encode('ascii', errors='ignore')
    .str.decode('utf-8'),
    nccenr_noponc=lambda x: x['nccenr'].str.replace('[^\w\s]', ' '),
    libelle_noponc=lambda x: x['libelle'].str.replace('[^\w\s]', ' '),
    noaccent_noponc=lambda x: x['noaccent'].str.replace('[^\w\s]', ' '),
    uppercase=lambda x: x.index,
    nccenr_uppercase=lambda x: x['nccenr'].str.upper(),
    libelle_uppercase=lambda x: x['libelle'].str.upper(),
    noaccent_uppercase=lambda x: x['noaccent'].str.upper(),
    nccenr_noponc_uppercase=lambda x: x['nccenr_noponc'].str.upper(),
    libelle_noponc_uppercase=lambda x: x['libelle_noponc'].str.upper(),
    noaccent_noponc_uppercase=lambda x: x['noaccent_noponc'].str.upper(),
    nccenr_lowercase=lambda x: x['nccenr'].str.lower(),
    libelle_lowercase=lambda x: x['libelle'].str.lower(),
    noaccent_lowercase=lambda x: x['noaccent'].str.lower(),
    nccenr_noponc_lowercase=lambda x: x['nccenr_noponc'].str.lower(),
    libelle_noponc_lowercase=lambda x: x['libelle_noponc'].str.lower(),
    noaccent_noponc_lowercase=lambda x: x['noaccent_noponc'].str.lower(),
    nccenr_noarrond1=lambda x: x['nccenr'].str.replace(
        'er Arrondissement', ''),
    uppercase_noarrond1=lambda x: x['uppercase'].str.replace(
        'ER ARRONDISSEMENT', ''),
    lowercase_noarrond1=lambda x: x['nccenr_lowercase'].str.replace(
        'er arrondissement', ''),
    nccenr_noarrond=lambda x: x['nccenr'].str.replace('e Arrondissement', ''),
    uppercase_noarrond=lambda x: x['uppercase'].str.replace(
        'E ARRONDISSEMENT', ''),
    lowercase_noarrond=lambda x: x['nccenr_lowercase'].str.replace(
        'e arrondissement', ''),
)
)

for n in communes.columns:
    var_ = '{}_ST'.format(n)
    var_1 = '{}_st'.format(n)
    var_2 = '{}_St'.format(n)
    
    communes[var_] = communes[n].str.replace('SAINT', 'ST')
    communes[var_1] = communes[n].str.replace('Saint', 'st')
    communes[var_2] = communes[n].str.replace('Saint', 'St')
    
    var_ = '{}_Sbar'.format(n)
    var_1 = '{}_sbar'.format(n)
    
    communes[var_] = communes[n].str.replace('SUR', 'S/')
    communes[var_1] = communes[n].str.replace('sur', 's/')
    
communes
# Out:
#                            ncc              possibilite  \
# 0        ABERGEMENT CLEMENCIAT    Abergement-Clémenciat
# 1        ABERGEMENT CLEMENCIAT  L'Abergement-Clémenciat
# 2        ABERGEMENT CLEMENCIAT    Abergement-Clemenciat
# 3        ABERGEMENT CLEMENCIAT    Abergement Clémenciat
# 4        ABERGEMENT CLEMENCIAT  L Abergement Clémenciat
# ...                        ...                      ...
# 5689206                   SADA                     SADA
# 5689213                   SADA                     sada
# 5689350               TSINGONI                 Tsingoni
# 5689356               TSINGONI                 TSINGONI
# 5689363               TSINGONI                 tsingoni
#
#                         ncc_ST                 ncc_st                 ncc_St  \
# 0        ABERGEMENT CLEMENCIAT  ABERGEMENT CLEMENCIAT  ABERGEMENT CLEMENCIAT
# 1        ABERGEMENT CLEMENCIAT  ABERGEMENT CLEMENCIAT  ABERGEMENT CLEMENCIAT
# 2        ABERGEMENT CLEMENCIAT  ABERGEMENT CLEMENCIAT  ABERGEMENT CLEMENCIAT
# 3        ABERGEMENT CLEMENCIAT  ABERGEMENT CLEMENCIAT  ABERGEMENT CLEMENCIAT
# 4        ABERGEMENT CLEMENCIAT  ABERGEMENT CLEMENCIAT  ABERGEMENT CLEMENCIAT
# ...                        ...                    ...                    ...
# 5689206                   SADA                   SADA                   SADA
# 5689213                   SADA                   SADA                   SADA
# 5689350               TSINGONI               TSINGONI               TSINGONI
# 5689356               TSINGONI               TSINGONI               TSINGONI
# 5689363               TSINGONI               TSINGONI               TSINGONI
#
#                       ncc_Sbar               ncc_sbar  \
# 0        ABERGEMENT CLEMENCIAT  ABERGEMENT CLEMENCIAT
# 1        ABERGEMENT CLEMENCIAT  ABERGEMENT CLEMENCIAT
# 2        ABERGEMENT CLEMENCIAT  ABERGEMENT CLEMENCIAT
# 3        ABERGEMENT CLEMENCIAT  ABERGEMENT CLEMENCIAT
# 4        ABERGEMENT CLEMENCIAT  ABERGEMENT CLEMENCIAT
# ...                        ...                    ...
# 5689206                   SADA                   SADA
# 5689213                   SADA                   SADA
# 5689350               TSINGONI               TSINGONI
# 5689356               TSINGONI               TSINGONI
# 5689363               TSINGONI               TSINGONI
#
#                   possibilite_ST           possibilite_st  \
# 0          Abergement-Clémenciat    Abergement-Clémenciat
# 1        L'Abergement-Clémenciat  L'Abergement-Clémenciat
# 2          Abergement-Clemenciat    Abergement-Clemenciat
# 3          Abergement Clémenciat    Abergement Clémenciat
# 4        L Abergement Clémenciat  L Abergement Clémenciat
# ...                          ...                      ...
# 5689206                     SADA                     SADA
# 5689213                     sada                     sada
# 5689350                 Tsingoni                 Tsingoni
# 5689356                 TSINGONI                 TSINGONI
# 5689363                 tsingoni                 tsingoni
#
#                   possibilite_St  ...      possibilite_Sbar_ST  \
# 0          Abergement-Clémenciat  ...    Abergement-Clémenciat
# 1        L'Abergement-Clémenciat  ...  L'Abergement-Clémenciat
# 2          Abergement-Clemenciat  ...    Abergement-Clemenciat
# 3          Abergement Clémenciat  ...    Abergement Clémenciat
# 4        L Abergement Clémenciat  ...  L Abergement Clémenciat
# ...                          ...  ...                      ...
# 5689206                     SADA  ...                     SADA
# 5689213                     sada  ...                     sada
# 5689350                 Tsingoni  ...                 Tsingoni
# 5689356                 TSINGONI  ...                 TSINGONI
# 5689363                 tsingoni  ...                 tsingoni
#
#              possibilite_Sbar_st      possibilite_Sbar_St  \
# 0          Abergement-Clémenciat    Abergement-Clémenciat
# 1        L'Abergement-Clémenciat  L'Abergement-Clémenciat
# 2          Abergement-Clemenciat    Abergement-Clemenciat
# 3          Abergement Clémenciat    Abergement Clémenciat
# 4        L Abergement Clémenciat  L Abergement Clémenciat
# ...                          ...                      ...
# 5689206                     SADA                     SADA
# 5689213                     sada                     sada
# 5689350                 Tsingoni                 Tsingoni
# 5689356                 TSINGONI                 TSINGONI
# 5689363                 tsingoni                 tsingoni
#
#            possibilite_Sbar_Sbar    possibilite_Sbar_sbar  \
# 0          Abergement-Clémenciat    Abergement-Clémenciat
# 1        L'Abergement-Clémenciat  L'Abergement-Clémenciat
# 2          Abergement-Clemenciat    Abergement-Clemenciat
# 3          Abergement Clémenciat    Abergement Clémenciat
# 4        L Abergement Clémenciat  L Abergement Clémenciat
# ...                          ...                      ...
# 5689206                     SADA                     SADA
# 5689213                     sada                     sada
# 5689350                 Tsingoni                 Tsingoni
# 5689356                 TSINGONI                 TSINGONI
# 5689363                 tsingoni                 tsingoni
#
#              possibilite_sbar_ST      possibilite_sbar_st  \
# 0          Abergement-Clémenciat    Abergement-Clémenciat
# 1        L'Abergement-Clémenciat  L'Abergement-Clémenciat
# 2          Abergement-Clemenciat    Abergement-Clemenciat
# 3          Abergement Clémenciat    Abergement Clémenciat
# 4        L Abergement Clémenciat  L Abergement Clémenciat
# ...                          ...                      ...
# 5689206                     SADA                     SADA
# 5689213                     sada                     sada
# 5689350                 Tsingoni                 Tsingoni
# 5689356                 TSINGONI                 TSINGONI
# 5689363                 tsingoni                 tsingoni
#
#              possibilite_sbar_St    possibilite_sbar_Sbar  \
# 0          Abergement-Clémenciat    Abergement-Clémenciat
# 1        L'Abergement-Clémenciat  L'Abergement-Clémenciat
# 2          Abergement-Clemenciat    Abergement-Clemenciat
# 3          Abergement Clémenciat    Abergement Clémenciat
# 4        L Abergement Clémenciat  L Abergement Clémenciat
# ...                          ...                      ...
# 5689206                     SADA                     SADA
# 5689213                     sada                     sada
# 5689350                 Tsingoni                 Tsingoni
# 5689356                 TSINGONI                 TSINGONI
# 5689363                 tsingoni                 tsingoni
#
#            possibilite_sbar_sbar
# 0          Abergement-Clémenciat
# 1        L'Abergement-Clémenciat
# 2          Abergement-Clemenciat
# 3          Abergement Clémenciat
# 4        L Abergement Clémenciat
# ...                          ...
# 5689206                     SADA
# 5689213                     sada
# 5689350                 Tsingoni
# 5689356                 TSINGONI
# 5689363                 tsingoni
#
# [245213 rows x 62 columns]

# %%
 (communes
            .stack()
            .rename('possibilite')
            .reset_index()
            .drop(columns='level_1')
            .drop_duplicates(subset=['possibilite']))
# Out:
#           level_0              possibilite
# 0               0    ABERGEMENT CLEMENCIAT
# 1               0    Abergement-Clémenciat
# 63              1  L'Abergement-Clémenciat
# 125             2    Abergement-Clemenciat
# 187             3    Abergement Clémenciat
# ...           ...                      ...
# 15202835  5689200                     Sada
# 15202959  5689213                     sada
# 15203020  5689350                 TSINGONI
# 15203021  5689350                 Tsingoni
# 15203145  5689363                 tsingoni
#
# [247555 rows x 2 columns]

# %%
communes = (df
            .set_index('ncc')
            .reindex(columns=['nccenr', 'libelle'])
            .assign(
    noaccent=lambda x: x['nccenr'].str.normalize('NFKD')
    .str.encode('ascii', errors='ignore')
    .str.decode('utf-8'),
    nccenr_noponc=lambda x: x['nccenr'].str.replace('[^\w\s]', ' '),
    libelle_noponc=lambda x: x['libelle'].str.replace('[^\w\s]', ' '),
    noaccent_noponc=lambda x: x['noaccent'].str.replace('[^\w\s]', ' '),
    uppercase=lambda x: x.index,
    nccenr_uppercase=lambda x: x['nccenr'].str.upper(),
    libelle_uppercase=lambda x: x['libelle'].str.upper(),
    noaccent_uppercase=lambda x: x['noaccent'].str.upper(),
    nccenr_noponc_uppercase=lambda x: x['nccenr_noponc'].str.upper(),
    libelle_noponc_uppercase=lambda x: x['libelle_noponc'].str.upper(),
    noaccent_noponc_uppercase=lambda x: x['noaccent_noponc'].str.upper(),
    nccenr_lowercase=lambda x: x['nccenr'].str.lower(),
    libelle_lowercase=lambda x: x['libelle'].str.lower(),
    noaccent_lowercase=lambda x: x['noaccent'].str.lower(),
    nccenr_noponc_lowercase=lambda x: x['nccenr_noponc'].str.lower(),
    libelle_noponc_lowercase=lambda x: x['libelle_noponc'].str.lower(),
    noaccent_noponc_lowercase=lambda x: x['noaccent_noponc'].str.lower(),
    nccenr_noarrond1=lambda x: x['nccenr'].str.replace(
        'er Arrondissement', ''),
    uppercase_noarrond1=lambda x: x['uppercase'].str.replace(
        'ER ARRONDISSEMENT', ''),
    lowercase_noarrond1=lambda x: x['nccenr_lowercase'].str.replace(
        'er arrondissement', ''),
    nccenr_noarrond=lambda x: x['nccenr'].str.replace('e Arrondissement', ''),
    uppercase_noarrond=lambda x: x['uppercase'].str.replace(
        'E ARRONDISSEMENT', ''),
    lowercase_noarrond=lambda x: x['nccenr_lowercase'].str.replace(
        'e arrondissement', ''),
)
)

for n in communes.columns:
    var_ = '{}_ST'.format(n)
    var_1 = '{}_st'.format(n)
    var_2 = '{}_St'.format(n)
    
    communes[var_] = communes[n].str.replace('SAINT', 'ST')
    communes[var_1] = communes[n].str.replace('Saint', 'st')
    communes[var_2] = communes[n].str.replace('Saint', 'St')
    
    var_ = '{}_Sbar'.format(n)
    var_1 = '{}_sbar'.format(n)
    
    communes[var_] = communes[n].str.replace('SUR', 'S/')
    communes[var_1] = communes[n].str.replace('sur', 's/')
    
communes = (communes
            .stack()
            .rename('possibilite')
            .reset_index()
            .drop(columns='level_1')
            .drop_duplicates(subset=['possibilite']))
communes.head()
# Out:
#                      ncc              possibilite
# 0  ABERGEMENT CLEMENCIAT    Abergement-Clémenciat
# 1  ABERGEMENT CLEMENCIAT  L'Abergement-Clémenciat
# 2  ABERGEMENT CLEMENCIAT    Abergement-Clemenciat
# 3  ABERGEMENT CLEMENCIAT    Abergement Clémenciat
# 4  ABERGEMENT CLEMENCIAT  L Abergement Clémenciat

# %%
communes.loc[lambda x: x['possibilite'].isin(['Soisy-sur-Seine'])]
# Out:
#                      ncc      possibilite           ncc_ST           ncc_st  \
# 5619750  SOISY SUR SEINE  Soisy-sur-Seine  SOISY SUR SEINE  SOISY SUR SEINE
#
#                   ncc_St        ncc_Sbar         ncc_sbar   possibilite_ST  \
# 5619750  SOISY SUR SEINE  SOISY S/ SEINE  SOISY SUR SEINE  Soisy-sur-Seine
#
#           possibilite_st   possibilite_St  ... possibilite_Sbar_ST  \
# 5619750  Soisy-sur-Seine  Soisy-sur-Seine  ...     Soisy-sur-Seine
#
#         possibilite_Sbar_st possibilite_Sbar_St possibilite_Sbar_Sbar  \
# 5619750     Soisy-sur-Seine     Soisy-sur-Seine       Soisy-sur-Seine
#
#         possibilite_Sbar_sbar possibilite_sbar_ST possibilite_sbar_st  \
# 5619750        Soisy-s/-Seine      Soisy-s/-Seine      Soisy-s/-Seine
#
#         possibilite_sbar_St possibilite_sbar_Sbar possibilite_sbar_sbar
# 5619750      Soisy-s/-Seine        Soisy-s/-Seine        Soisy-s/-Seine
#
# [1 rows x 62 columns]

# %%
df.loc[lambda x: x['ncc'].isin(['SOISY SUR SEINE'])]
# Out:
#       typecom    com   reg dep  arr  tncc              ncc           nccenr  \
# 37465     COM  91600  11.0  91  912     0  SOISY SUR SEINE  Soisy-sur-Seine
#
#                libelle   can  comparent
# 37465  Soisy-sur-Seine  9106        NaN

# %% [markdown]
# ## Creation libelleVoieEtablissement
#
# `libelleVoieEtablissement.csv`:
# CSV recréé via extraction des données depuis site https://www.sirene.fr/sirene/public/variable/libelleVoieEtablissement

# %%
libelle = 'https://scm.saas.cagip.group.gca/PERNETTH/inseeinpi_matching/raw' \
'/master/Notebooks_matching/Data_preprocessed/programme_matching/data/input' \
'/RawParameters/libelleVoieEtablissement.csv'

# %%
voie = pd.read_csv(libelle)
voie.head()

# %%
(voie.assign(upper_clean = lambda x: x['possibilite'].str.normalize(
                'NFKD')
            .str.encode('ascii', errors='ignore')
            .str.decode('utf-8')
            .str.replace('[^\w\s]|\d+', ' ')
            .str.upper(),
            lower_clean = lambda x: x['possibilite'].str.normalize(
                'NFKD')
            .str.encode('ascii', errors='ignore')
            .str.decode('utf-8')
            .str.replace('[^\w\s]|\d+', ' ')
            .str.lower()
        )
 .set_index('INSEE')
 .unstack() 
 .reset_index()
 #.drop(columns = 'level_0')
 .iloc[:,1:]
 .rename(columns = {0: 'possibilite'})
 .sort_values(by = 'INSEE')
 #.to_csv(r'data\input\voie.csv', index = False)
)

# %% [markdown]
# # Formz juridique INSEE/INPI
#
# Pour siretiser les personnes morales, il faut utliser le champs forme juridique qui est sous forme de code à l'INSEE mais sous forme textuelle à l'INPI.
#
# - La donnée de l'insee vient de cette URL https://www.insee.fr/fr/information/2028129
#     - A noter qu'il y a un espace dans le libellé a la fin, du coup on l'a enlevé avant de renvoyer dans le S3
# - La donnée de l'INPI vient de cette query https://eu-west-3.console.aws.amazon.com/athena/home?region=eu-west-3#query/history/870c671d-d51c-473a-9478-64218961d91a

# %%
from awsPy.aws_authorization import aws_connector
from awsPy.aws_s3 import service_s3
from awsPy.aws_athena import service_athena
import os, time
from pathlib import Path

# %%
bucket = 'calfdata'
path = os.getcwd()
parent_path = str(Path(path).parent)
path_cred = "{}/credential_AWS.json".format(parent_path)
con = aws_connector.aws_instantiate(credential = path_cred,
                                        region = 'eu-west-3')
client= con.client_boto()
s3 = service_s3.connect_S3(client = client,
                      bucket = 'calfdata') 
athena = service_athena.connect_athena(client = client,
                      bucket = 'calfdata')

# %%
inpi = s3.read_df_from_s3(key = 'INPI/TC_1/02_preparation_donnee/intermediate_file/forme_juridique_inpi.csv',
                sep = ',',encoding = None)
inpi.shape

# %%
inpi_raw = s3.read_df_from_s3(
    'INPI/TC_1/02_preparation_donnee/intermediate_file/forme_juridique_inpi_origin.csv',
sep = ',',encoding = None)
inpi_raw.shape

# %%
inpi.assign(Libellé = lambda x: 
         x['Libellé'].str.rstrip()).merge(inpi_raw,
           left_on = ['Libellé'],
          right_on = ['forme_juridique'],
                                          how = 'outer',
                                          indicator = True
                                         ).to_excel('missing_forme_juridique.xlsx', 
                                                  index= False)

# %%
insee = s3.read_df_from_s3(key = 'INPI/TC_1/02_preparation_donnee/intermediate_file/forme_juridique_insee.csv',
                sep = ',',encoding = None)
insee.shape

# %%
(insee
 .assign(Libellé = lambda x: 
         x['Libellé'].str.rstrip())
 .merge(inpi, left_on = ['Libellé'], right_on = ['forme_juridique'], 
        how = 'right',
       indicator = True))

# %%
insee.assign(Libellé = lambda x: 
         x['Libellé'].str.rstrip()
            ).to_csv('forme_juridique_insee_cleaned.csv', index = False)
s3.upload_file('forme_juridique_insee_cleaned.csv',
            destination_in_s3=  'INPI/TC_1/02_preparation_donnee/intermediate_for_athena/forme_juridique_insee_cleaned.csv'
           )

# %%
insee.head()

# %%
query_tb = """CREATE EXTERNAL TABLE IF NOT EXISTS inpi.forme_juridique (
    `Libellé` string,
    `Code` string
    )
     ROW FORMAT SERDE 'org.apache.hadoop.hive.serde2.OpenCSVSerde'
    WITH SERDEPROPERTIES (
   'separatorChar' = ',',
   'quoteChar' = '"'
   )
     LOCATION 's3://calfdata/INPI/TC_1/02_preparation_donnee/intermediate_for_athena'
     TBLPROPERTIES ('has_encrypted_data'='false',
              'skip.header.line.count'='1');"""
athena.run_query(query_tb,
                 database='inpi',
                 s3_output='INSEE/sql_output'
                )
